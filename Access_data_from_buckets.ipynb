# %%
import pandas as pd
import s3fs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-1014b264e853> in <module>()
#       1 import pandas as pd
# ----> 2 import s3fs
#
# ModuleNotFoundError: No module named 's3fs'

# %%
# !pip install s3fs
# Out:
# ...
#     100% |████████████████████████████████| 143kB 8.3MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 61kB 12.3MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 1.1MB 11.8MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 8.4MB 2.4MB/s eta 0:00:01    23% |███████▋                        | 2.0MB 22.7MB/s eta 0:00:01    38% |████████████▎                   | 3.2MB 27.2MB/s eta 0:00:01    66% |█████████████████████▍          | 5.6MB 24.8MB/s eta 0:00:01
# ...
#     100% |████████████████████████████████| 81kB 14.1MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 163kB 17.4MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 194kB 15.5MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 276kB 15.7MB/s ta 0:00:01
# ...
#     100% |████████████████████████████████| 143kB 17.9MB/s ta 0:00:01
# ...
#   Running setup.py bdist_wheel for aiobotocore ... done
# ...

# %%
ser = pd.read_json('s3://udacity-dend/song_data/A/B/C/TRABCEI128F424C983.json', typ='series')

# %%
ser.to_frame('count')
# Out:
#                                 count
# artist_id          ARJIE2Y1187B994AB7
# artist_latitude                  None
# artist_location
# artist_longitude                 None
# artist_name               Line Renaud
# duration                       152.92
# num_songs                           1
# song_id            SOUPIRU12A6D4FA1E1
# title             Der Kleine Dompfaff
# year                                0

# %%
ser = pd.read_json('s3://udacity-dend/log_data/2018/11/2018-11-12-events.json',lines=True)

# %%
ser.dtypes
# Out:
# artist            object
# auth              object
# firstName         object
# gender            object
# itemInSession      int64
# lastName          object
# length           float64
# level             object
# location          object
# method            object
# page              object
# registration     float64
# sessionId          int64
# song              object
# status             int64
# ts                 int64
# userAgent         object
# userId            object
# dtype: object

# %%
ser
# Out:
#                                                 artist        auth  \
# 0                                                 None   Logged In
# 1                                             Pavement   Logged In
# 2    Barry Tuckwell/Academy of St Martin-in-the-Fie...   Logged In
# 3                                           Gary Allan   Logged In
# 4                                                 None   Logged In
# 5                                   Charttraxx Karaoke   Logged In
# 6                                       The Libertines   Logged In
# 7                              Huey Lewis And The News   Logged In
# 8                              JOSEF LOCKE & ORCHESTRA   Logged In
# 9                                                Train   Logged In
# 10                                         Blind Pilot   Logged In
# 11                                             Anjulie   Logged In
# 12                                   59 Times the Pain   Logged In
# ...
